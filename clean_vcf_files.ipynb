# %% [markdown]
# # Remove extraneous exomic information
# ##### Updated 06/03/2024
# ##### Selin Kubali
#
# #### Goal:
# This notebook takes VCF files generated by vcfByGene and removes headers and info columns.
#
# #### Required inputs
# VCF files with chrom, pos, ref, and alt information. Found in *selected_genes/hcm/vcf_files/*
#
# #### Output
# Truncated VCF files. Output to */selected_genes/hcm/cleaned_vcf_files*

# %%
# download vcf files generated by vcfByGene
# !dx cd "Cassa Lab Shared Project:selected_genes/hcm/vcf_files/"
# !dx download *_variants.vcf.gz
# Out:
# [===========================================================>] Completed 1,502,681,057 of 1,502,681,057 bytes (100%) /opt/notebooks/FLNC_variants.vcf.gzz
# [===========================================================>] Completed 1,544,977,714 of 1,544,977,714 bytes (100%) /opt/notebooks/MYH7_variants.vcf.gzz
# [===========================================================>] Completed 1,633,005,600 of 1,633,005,600 bytes (100%) /opt/notebooks/MYH6_variants.vcf.gzz
# [===========================================================>] Completed 1,067,022,426 of 1,067,022,426 bytes (100%) /opt/notebooks/MYBPC3_variants.vcf.gzz
# [===========================================================>] Completed 1,267,184,117 of 1,267,184,117 bytes (100%) /opt/notebooks/ALPK3_variants.vcf.gzz
# [===========================================================>] Completed 1,368,598,266 of 1,368,598,266 bytes (100%) /opt/notebooks/FHOD3_variants.vcf.gzz
# [===========================================================>] Completed 794,893,312 of 794,893,312 bytes (100%) /opt/notebooks/ACTN2_variants.vcf.gzz
# [===========================================================>] Completed 302,674,313 of 302,674,313 bytes (100%) /opt/notebooks/TNNT2_variants.vcf.gzz
# [===========================================================>] Completed 416,897,440 of 416,897,440 bytes (100%) /opt/notebooks/DES_variants.vcf.gzz
# [===========================================================>] Completed 446,489,167 of 446,489,167 bytes (100%) /opt/notebooks/TRIM63_variants.vcf.gzz
# [===========================================================>] Completed 344,367,590 of 344,367,590 bytes (100%) /opt/notebooks/TPM1_variants.vcf.gzz
# [===========================================================>] Completed 328,590,551 of 328,590,551 bytes (100%) /opt/notebooks/PTPN11_variants.vcf.gzz
# [===========================================================>] Completed 119,469,475 of 119,469,475 bytes (100%) /opt/notebooks/TNNI3_variants.vcf.gzz
# [===========================================================>] Completed 209,875,188 of 209,875,188 bytes (100%) /opt/notebooks/CSRP3_variants.vcf.gzz
# [===========================================================>] Completed 215,761,802 of 215,761,802 bytes (100%) /opt/notebooks/JPH2_variants.vcf.gzz
# [===========================================================>] Completed 195,340,565 of 195,340,565 bytes (100%) /opt/notebooks/MYL2_variants.vcf.gzz
# [===========================================================>] Completed 164,974,949 of 164,974,949 bytes (100%) /opt/notebooks/ACTC1_variants.vcf.gzz
# [===========================================================>] Completed 199,586,850 of 199,586,850 bytes (100%) /opt/notebooks/MYL3_variants.vcf.gzz
# [===========================================================>] Completed 148,081,567 of 148,081,567 bytes (100%) /opt/notebooks/TTR_variants.vcf.gzz
# [===========================================================>] Completed 64,741,703 of 64,741,703 bytes (100%) /opt/notebooks/PLN_variants.vcf.gzz

# %%
# unzip vcf files
# !gzip -d *_variants.vcf.gz

# %%
## cut out header and information related to patient genotypes from VCF files
# you may have to switch to a bash kernel for this and switch back to a python kernel
for vcf_file in *.vcf; do
  # Remove lines starting with '##' and then use 'cut' to extract fields 1-9
  grep -v '^##' "$vcf_file" | cut -d$'\t' -f 1-9 > "${vcf_file%.vcf}_cleaned.vcf"
done

# %%
# upload processed VCFs
# !dx mkdir -p "Cassa Lab Shared Project:selected_genes/hcm/cleaned_vcf_files/"
# !dx cd /selected_genes/hcm/cleaned_vcf_files/
# !dx upload *.vcf
# Out:
# [===========================================================>] Uploaded 34,556 of 34,556 bytes (100%) ACTC1_variants_cleaned.vcf
# ID                          file-GkGGgjjJqBj0kvKBf1YQv1vx
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        ACTC1_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:35 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:36 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 139,897 of 139,897 bytes (100%) ACTN2_variants_cleaned.vcf
# ID                          file-GkGGgk0JqBj378zkxxfVzgGz
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        ACTN2_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:36 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:37 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 197,591 of 197,591 bytes (100%) ALPK3_variants_cleaned.vcf
# ID                          file-GkGGgk8JqBj8v3PF9gXF6zFB
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        ALPK3_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:37 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:38 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 44,219 of 44,219 bytes (100%) CSRP3_variants_cleaned.vcf
# ID                          file-GkGGgkQJqBj378zkxxfVzgJ1
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        CSRP3_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:38 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:39 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 54,717 of 54,717 bytes (100%) DES_variants_cleaned.vcf
# ID                          file-GkGGgkjJqBjFqjGPy6X9gkg9
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        DES_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:39 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:40 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 230,775 of 230,775 bytes (100%) FHOD3_variants_cleaned.vcf
# ID                          file-GkGGgp0JqBj0kvKBf1YQv1vz
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        FHOD3_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:40 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:41 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 234,222 of 234,222 bytes (100%) FLNC_variants_cleaned.vcf
# ID                          file-GkGGgp8JqBj9bF97Q0QKZX4P
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        FLNC_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:41 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:42 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 28,235 of 28,235 bytes (100%) JPH2_variants_cleaned.vcf
# ID                          file-GkGGgpQJqBj0kvKBf1YQv1x3
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        JPH2_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:42 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:43 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 148,629 of 148,629 bytes (100%) MYBPC3_variants_cleaned.vcf
# ID                          file-GkGGgpjJqBj2Bxj1j65ky41X
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        MYBPC3_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:43 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:44 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 247,903 of 247,903 bytes (100%) MYH6_variants_cleaned.vcf
# ID                          file-GkGGgq0JqBj8v3PF9gXF6zFK
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        MYH6_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:44 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:45 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 218,563 of 218,563 bytes (100%) MYH7_variants_cleaned.vcf
# ID                          file-GkGGgq8JqBj378zkxxfVzgJB
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        MYH7_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:45 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:46 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 39,452 of 39,452 bytes (100%) MYL2_variants_cleaned.vcf
# ID                          file-GkGGgqQJqBj0kvKBf1YQv1x5
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        MYL2_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:46 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:47 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 32,670 of 32,670 bytes (100%) MYL3_variants_cleaned.vcf
# ID                          file-GkGGgqjJqBj9bF97Q0QKZX50
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        MYL3_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:47 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:48 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 13,125 of 13,125 bytes (100%) PLN_variants_cleaned.vcf
# ID                          file-GkGGgv0JqBj0kvKBf1YQv1x9
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        PLN_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:48 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:49 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 68,391 of 68,391 bytes (100%) PTPN11_variants_cleaned.vcf
# ID                          file-GkGGgv8JqBj378zkxxfVzgJJ
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        PTPN11_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:49 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:50 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 25,217 of 25,217 bytes (100%) TNNI3_variants_cleaned.vcf
# ID                          file-GkGGgvQJqBj8v3PF9gXF6zFZ
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        TNNI3_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:50 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:51 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 53,974 of 53,974 bytes (100%) TNNT2_variants_cleaned.vcf
# ID                          file-GkGGgvjJqBj8v3PF9gXF6zFf
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        TNNT2_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:51 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:52 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 47,120 of 47,120 bytes (100%) TPM1_variants_cleaned.vcf
# ID                          file-GkGGgx0JqBjFqjGPy6X9gkgq
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        TPM1_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:52 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:56:53 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 5,746,905,140 of 5,746,905,140 bytes (100%) TRIM63_variants.vcf
# ID                          file-GkGGgx8JqBj2Bxj1j65ky449
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        TRIM63_variants.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:56:53 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:57:02 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 78,205 of 78,205 bytes (100%) TRIM63_variants_cleaned.vcf
# ID                          file-GkGGgzQJqBjFf5JjK5q1xj4b
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        TRIM63_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:57:02 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:57:03 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 2,145,194,811 of 2,145,194,811 bytes (100%) TTR_variants.vcf
# ID                          file-GkGGgzjJqBj56By50075YYJY
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        TTR_variants.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:57:03 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:57:07 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 29,648 of 29,648 bytes (100%) TTR_variants_cleaned.vcf
# ID                          file-GkGGj0jJqBj2982VXybKKj36
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/cleaned_vcf_files
# Name                        TTR_variants_cleaned.vcf
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:57:07 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:57:08 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
