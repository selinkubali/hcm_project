# %% [markdown]
# # Loading AlphaMissense data
# ##### Updated 06/03/2024
# ##### Selin Kubali
#
# #### Goal:
# Extract gnomAD information for all exomes in each given gene.
#
# #### Required inputs
# - MANE guide, found in *selected_genes/hcm/csv_files/MANE.GRCh38.v1.0.select_ensembl_genomic.csv.gz*.
# - gnomAD VCFs for each gene. Found in *selected_genes/hcm/gnomAD/gnomAD_gene_vcfs
#
# #### Output
# CSV files containing gnomAD information – CADD, phyloP, allele frequency max, SpliceAI max, REVEL, Ensembl VEP consequence and confidence for canonical transcripts – for given genes. Uploaded to . Found in *selected_genes/hcm/gnomAD/gnomAD_csvs*.

# %% [markdown]
# ## Load packages

# %%
import sys
import pandas as pd
import numpy as np
from multiprocessing import Pool

# %% [markdown]
# ## List of genes

# %%
genes = ["ACTN2", "ALPK3", "DES", "FLNC", "MYBPC3", "MYH6", "MYH7", "PLN", "PTPN11", "TNNI3", "TTR", "TNNT2", "TPM1", "MYL2", "MYL3", "ACTC1", "JPH2", "FHOD3", "CSRP3", "TRIM63"]

# %% [markdown]
# ## Download VCFs

# %%
# !dx cd selected_genes/hcm/gnomAD/gnomAD_gene_vcfs
# !dx download vcf_*.gz
# Out:
# [===========================================================>] Completed 1,892,369 of 1,892,369 bytes (100%) /opt/notebooks/vcf_for_TNNT2.gzz
# [===========================================================>] Completed 1,479,788 of 1,479,788 bytes (100%) /opt/notebooks/vcf_for_TRIM63.gzz
# [===========================================================>] Completed 6,789,034 of 6,789,034 bytes (100%) /opt/notebooks/vcf_for_MYBPC3.gzz
# [===========================================================>] Completed 993,614 of 993,614 bytes (100%) /opt/notebooks/vcf_for_PLN.gzz
# [===========================================================>] Completed 3,868,349 of 3,868,349 bytes (100%) /opt/notebooks/vcf_for_ACTN2.gzz
# [===========================================================>] Completed 2,522,261 of 2,522,261 bytes (100%) /opt/notebooks/vcf_for_DES.gzz
# [===========================================================>] Completed 746,027 of 746,027 bytes (100%) /opt/notebooks/vcf_for_MYL3.gzz
# [===========================================================>] Completed 6,821,059 of 6,821,059 bytes (100%) /opt/notebooks/vcf_for_FLNC.gzz
# [===========================================================>] Completed 3,269,403 of 3,269,403 bytes (100%) /opt/notebooks/vcf_for_MYH7.gzz
# [===========================================================>] Completed 3,722,483 of 3,722,483 bytes (100%) /opt/notebooks/vcf_for_MYH6.gzz
# [===========================================================>] Completed 3,076,845 of 3,076,845 bytes (100%) /opt/notebooks/vcf_for_PTPN11.gzz
# [===========================================================>] Completed 901,500 of 901,500 bytes (100%) /opt/notebooks/vcf_for_CSRP3.gzz
# [===========================================================>] Completed 7,481,142 of 7,481,142 bytes (100%) /opt/notebooks/vcf_for_FHOD3.gzz
# [===========================================================>] Completed 672,749 of 672,749 bytes (100%) /opt/notebooks/vcf_for_ACTC1.gzz
# [===========================================================>] Completed 1,209,856 of 1,209,856 bytes (100%) /opt/notebooks/vcf_for_TNNI3.gzz
# [===========================================================>] Completed 1,867,650 of 1,867,650 bytes (100%) /opt/notebooks/vcf_for_TPM1.gzz
# [===========================================================>] Completed 657,988 of 657,988 bytes (100%) /opt/notebooks/vcf_for_MYL2.gzz
# [===========================================================>] Completed 875,572 of 875,572 bytes (100%) /opt/notebooks/vcf_for_TTR.gzz
# [===========================================================>] Completed 3,725,425 of 3,725,425 bytes (100%) /opt/notebooks/vcf_for_JPH2.gzz
# [===========================================================>] Completed 5,591,349 of 5,591,349 bytes (100%) /opt/notebooks/vcf_for_ALPK3.gzz

# %% [markdown]
# ### Transform information given in gnomAD VCFs into a dataframe

# %%
def parse_string(info_str):
    """ Transform gnomAD data into a set of dictionaries """
    features = info_str.split(';')
    features_list = []
    for pair in features:
        # Split once again on vep
        if 'vep=' in pair:
            vep_split = pair.split('vep=')
            try:
                features_list.append(['vep', vep_split[1]])
            except:
                print(vep_split)
        elif '=' in pair:
            features_list.append(pair.split('='))



    features_dict = {key: value for key, value in features_list}
    filtered_features_dict = {key: features_dict.get(key, 'NA') for key in ['cadd_raw_score', 'phylop', 'fafmax_faf95_max', 'spliceai_ds_max', 'revel_max', 'vep']}
    return filtered_features_dict

# %%
def filter_list_of_lists(lst):
    """ Only add consequence for canonical transcripts from Ensembl VEP """
    list_of_lists = []
    for i in lst:
        if len(i) > 32:
            if (i[24] == 'YES') & (i[32] == 'Ensembl'):
                list_of_lists.append([i[1], i[3], i[24], i[32], i[42]])
    return list_of_lists

# %%
def fill_na(row):
    """ Add row of NAs where information is missing """
    if type(row) != list:
        return ['']*5
    else:
        return row

# %%
def clean_data(data):
    filtered_features_dict = data['Info'].apply(parse_string).tolist()
    # Convert provided dictionaries into dataframe 
    info_df = pd.DataFrame(filtered_features_dict)
    chrom_data = pd.concat([basic_data, info_df], axis=1)
    # Split information given in VEP and filter for canonical transcripts
    chrom_data['vep'] = chrom_data['vep'].apply(lambda x: x.split(','))
    chrom_data['vep'] = chrom_data['vep'].apply(lambda x: [item.split('|') for item in x])
    chrom_data['vep'] = chrom_data['vep'].apply(filter_list_of_lists)
    chrom_data = chrom_data.explode('vep')
    chrom_data['vep'] = chrom_data['vep'].apply(fill_na)
    # Convert VEP data into multiple columns
    chrom_data[['Consequence', 'Gene', 'Canonical', 'Source', 'Confidence']] = pd.DataFrame(chrom_data['vep'].tolist(), index=chrom_data.index)
    chrom_data.drop('vep', axis=1, inplace=True)
    return chrom_data

# %%
for gene in genes:
    data = pd.read_csv('vcf_for_'+gene+'.gz', sep = '\t', names = ['Chrom', 'Pos', 'ID', 'Ref', 'Alt', '?', 'Filter', 'Info'], usecols=['Chrom', 'Pos', 'Ref', 'Alt', 'Filter', 'Info'], low_memory=False,  comment='#', compression='gzip', memory_map=True)
    basic_data = data[['Chrom', 'Pos', 'Ref', 'Alt','Filter']]
    chrom_data = clean_data(data)
    chrom_data.to_csv(gene+'_gnomAD.csv')

# %%
# !dx mkdir -p /selected_genes/hcm/gnomAD/gnomAD_csvs
# !dx cd /selected_genes/hcm/gnomAD/gnomAD_csvs
# !dx upload *_gnomAD.csv
# Out:
# [===========================================================>] Uploaded 143,973 of 143,973 bytes (100%) ACTC1_gnomAD.csv
# ID                          file-GkGGkF8JqBjFp44xB4K3bjfP
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        ACTC1_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:59:57 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:59:58 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 308,542 of 308,542 bytes (100%) ACTN2_gnomAD.csv
# ID                          file-GkGGkFQJqBj9XyZ3X5F4j0jJ
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        ACTN2_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:59:58 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 18:59:59 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 841,534 of 841,534 bytes (100%) ALPK3_gnomAD.csv
# ID                          file-GkGGkFjJqBjFjzjv3V9ZXfxB
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        ALPK3_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 18:59:59 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:00 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 105,458 of 105,458 bytes (100%) CSRP3_gnomAD.csv
# ID                          file-GkGGkG0JqBj9KZy4FQG0Y10g
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        CSRP3_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:00 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:01 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 482,965 of 482,965 bytes (100%) DES_gnomAD.csv
# ID                          file-GkGGkG8JqBj9XyZ3X5F4j0jV
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        DES_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:01 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:02 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 471,680 of 471,680 bytes (100%) FHOD3_gnomAD.csv
# ID                          file-GkGGkGQJqBj9KZy4FQG0Y10z
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        FHOD3_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:02 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:03 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 1,302,219 of 1,302,219 bytes (100%) FLNC_gnomAD.csv
# ID                          file-GkGGkGjJqBjFjzjv3V9ZXfxQ
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        FLNC_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:03 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:04 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 606,744 of 606,744 bytes (100%) JPH2_gnomAD.csv
# ID                          file-GkGGkJ0JqBjFp44xB4K3bjgX
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        JPH2_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:04 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:05 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 726,914 of 726,914 bytes (100%) MYBPC3_gnomAD.csv
# ID                          file-GkGGkJ8JqBjFp44xB4K3bjgZ
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        MYBPC3_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:05 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:06 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 655,359 of 655,359 bytes (100%) MYH6_gnomAD.csv
# ID                          file-GkGGkJQJqBj9XyZ3X5F4j0jk
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        MYH6_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:06 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:07 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 712,244 of 712,244 bytes (100%) MYH7_gnomAD.csv
# ID                          file-GkGGkJjJqBjFjzjv3V9ZXfxp
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        MYH7_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:07 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:08 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 97,399 of 97,399 bytes (100%) MYL2_gnomAD.csv
# ID                          file-GkGGkK0JqBj0QYVzzK6B1p1X
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        MYL2_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:08 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:09 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 73,001 of 73,001 bytes (100%) MYL3_gnomAD.csv
# ID                          file-GkGGkK8JqBjFp44xB4K3bjgq
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        MYL3_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:09 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:10 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 185,452 of 185,452 bytes (100%) PLN_gnomAD.csv
# ID                          file-GkGGkKQJqBj9KZy4FQG0Y11K
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        PLN_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:10 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:11 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 314,917 of 314,917 bytes (100%) PTPN11_gnomAD.csv
# ID                          file-GkGGkKjJqBjP3kJx4x4yBFqY
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        PTPN11_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:11 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:12 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 343,565 of 343,565 bytes (100%) TNNI3_gnomAD.csv
# ID                          file-GkGGkP0JqBj9XyZ3X5F4j0kG
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        TNNI3_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:12 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:13 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 189,650 of 189,650 bytes (100%) TNNT2_gnomAD.csv
# ID                          file-GkGGkP8JqBj6v37zBg3XXgv2
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        TNNT2_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:13 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:14 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 129,234 of 129,234 bytes (100%) TPM1_gnomAD.csv
# ID                          file-GkGGkPjJqBj6ZYZ5P59KyV0Y
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        TPM1_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:15 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:15 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 257,680 of 257,680 bytes (100%) TRIM63_gnomAD.csv
# ID                          file-GkGGkQ0JqBj6v37zBg3XXgvK
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        TRIM63_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:16 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:16 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 36,263 of 36,263 bytes (100%) TTR_gnomAD.csv
# ID                          file-GkGGkQ0JqBj6ZYZ5P59KyV0z
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/gnomAD/gnomAD_csvs
# Name                        TTR_gnomAD.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:00:16 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:00:17 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
