# %%
from io import StringIO
import numpy as np
import pandas as pd
from subprocess import call
import re

# %% [markdown]
# # Loading AlphaMissense data
# ##### Updated 06/03/2024
# ##### Selin Kubali
#
# #### Goal:
# Extract AlphaMissense scores for all exomes in each given gene.
#
# #### Required inputs
# - MANE guide, found in *selected_genes/hcm/csv_files/MANE.GRCh38.v1.0.select_ensembl_genomic.csv.gz*.
# - AlphaMissense csv. Found in *selected_genes/hcm/csv_files/AlphaMissense_hg38.tsv
#
# #### Output
# CSV files containing AlphaMissense scores for exomes in each gene. Found in *selected_genes/hcm/alpha_missensense_annotated*.

# %%
exon_flank_nt = 5

# %% [markdown]
# ### List of gene symbols as input

# %%
genes = ["ACTN2", "ALPK3", "DES", "FLNC", "MYBPC3", "MYH6", "MYH7", "PLN", "PTPN11", "TNNI3", "TTR", "TNNT2", "TPM1", "MYL2", "MYL3", "ACTC1", "JPH2", "FHOD3", "CSRP3", "TRIM63"]

# %% [markdown]
# ### Load MANE transcript coordinates

# %%
df = pd.read_csv(f'/mnt/project/selected_genes/hcm/csv_files/MANE.GRCh38.v1.0.select_ensembl_genomic.csv.gz')
df = df.loc[(df['feature'] == 'exon') & (df['gene_name'].isin(genes))]
df = df[['seqname', 'start', 'end', 'gene_name']]
df['exon_flank_start'] = df['start'] - exon_flank_nt
df['exon_flank_end'] = df['end'] + exon_flank_nt
df['region'] = ((df['seqname'] + ':').str.cat(df['exon_flank_start'].astype(str)) + '-').str.cat(df['exon_flank_end'].astype(str))
df
# Out:
#        seqname     start       end gene_name  exon_flank_start  \
# 21285     chr1  26067336  26067630    TRIM63          26067331
# 21288     chr1  26066268  26066440    TRIM63          26066263
# 21290     chr1  26061166  26061334    TRIM63          26061161
# 21292     chr1  26060266  26060361    TRIM63          26060261
# 21294     chr1  26058390  26058623    TRIM63          26058385
# ...        ...       ...       ...       ...               ...
# 473557   chr20  44159618  44160407      JPH2          44159613
# 473559   chr20  44118505  44118623      JPH2          44118500
# 473561   chr20  44115665  44116386      JPH2          44115660
# 473563   chr20  44114782  44114876      JPH2          44114777
# 473566   chr20  44106590  44113503      JPH2          44106585
#
#         exon_flank_end                   region
# 21285         26067635   chr1:26067331-26067635
# 21288         26066445   chr1:26066263-26066445
# 21290         26061339   chr1:26061161-26061339
# 21292         26060366   chr1:26060261-26060366
# 21294         26058628   chr1:26058385-26058628
# ...                ...                      ...
# 473557        44160412  chr20:44159613-44160412
# 473559        44118628  chr20:44118500-44118628
# 473561        44116391  chr20:44115660-44116391
# 473563        44114881  chr20:44114777-44114881
# 473566        44113508  chr20:44106585-44113508
#
# [334 rows x 7 columns]

# %%
dtype_spec = {
"Chrom": str,
"Pos": int,
"Ref": str,
"Alt": str,
"genome": str,
"uniprot_id": str,
"transcript_id": str,
"protein_variant": str,
"am_pathogenicity": float,
"am_class": str
}
ai_scores = pd.read_csv(f'/mnt/project/selected_genes/hcm/csv_files/AlphaMissense_hg38.tsv', sep = "\t", skiprows = 4, names = ["Chrom", "Pos", "Ref", "Alt", "genome", "uniprot_id", "transcript_id", "protein_variant", "am_pathogenicity", "am_class"],usecols=["Chrom", "Pos", "Ref", "Alt","am_pathogenicity"])

# %%
def in_ranges(pos, ranges):
    for start, end in ranges:
        if start <= pos <= end:
            return True
    return False

# %%
for gene in genes:
    df_gene = df.loc[df['gene_name'] == gene]
    if df_gene.shape[0] > 0:
        
        combined = list(zip(df_gene['exon_flank_start'], df_gene['exon_flank_end']))
        ai_scores_gene = ai_scores[ai_scores['Pos'].apply(lambda x: in_ranges(x, combined))]
        ai_scores_gene.to_csv(gene+"_alphamissense.csv")

# %%
# !dx mkdir -p "Cassa Lab Shared Project:/selected_genes/hcm/alpha_missensense_annotated"
# !dx cd /selected_genes/hcm/alpha_missensense_annotated
# !dx upload *_alphamissense.csv
# Out:
# [===========================================================>] Uploaded 131,787 of 131,787 bytes (100%) ACTC1_alphamissense.csv
# ID                          file-GkGJQPjJqBj55bYxFQxZKJQJ
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        ACTC1_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:19 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:20 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 202,847 of 202,847 bytes (100%) ACTN2_alphamissense.csv
# ID                          file-GkGJQQ0JqBj9GVy87J61FPz3
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        ACTN2_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:20 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:21 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 533,293 of 533,293 bytes (100%) ALPK3_alphamissense.csv
# ID                          file-GkGJQQ8JqBjBfXj2kkF80Qk3
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        ALPK3_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:21 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:22 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 59,740 of 59,740 bytes (100%) CSRP3_alphamissense.csv
# ID                          file-GkGJQQQJqBj55bYxFQxZKJQY
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        CSRP3_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:22 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:23 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 106,642 of 106,642 bytes (100%) DES_alphamissense.csv
# ID                          file-GkGJQQjJqBj8qkvYf833x768
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        DES_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:23 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:24 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 378,539 of 378,539 bytes (100%) FHOD3_alphamissense.csv
# ID                          file-GkGJQV0JqBjBfXj2kkF80QkF
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        FHOD3_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:24 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:25 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 678,154 of 678,154 bytes (100%) FLNC_alphamissense.csv
# ID                          file-GkGJQV8JqBj55bYxFQxZKJQk
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        FLNC_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:25 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:26 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 591,087 of 591,087 bytes (100%) JPH2_alphamissense.csv
# ID                          file-GkGJQVQJqBj8qkvYf833x76j
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        JPH2_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:26 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:27 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 685,329 of 685,329 bytes (100%) MYBPC3_alphamissense.csv
# ID                          file-GkGJQVjJqBj43J0Y0g2J6Q3y
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        MYBPC3_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:27 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:28 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 546,470 of 546,470 bytes (100%) MYH6_alphamissense.csv
# ID                          file-GkGJQX0JqBj2V81F535JJK33
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        MYH6_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:28 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:29 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 516,998 of 516,998 bytes (100%) MYH7_alphamissense.csv
# ID                          file-GkGJQX8JqBj2V81F535JJK35
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        MYH7_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:29 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:30 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 40,461 of 40,461 bytes (100%) MYL2_alphamissense.csv
# ID                          file-GkGJQXQJqBj43J0Y0g2J6Q44
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        MYL2_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:30 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:31 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 67,194 of 67,194 bytes (100%) MYL3_alphamissense.csv
# ID                          file-GkGJQXjJqBj55bYxFQxZKJV1
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        MYL3_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:31 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:32 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 25,568 of 25,568 bytes (100%) PLN_alphamissense.csv
# ID                          file-GkGJQY0JqBj43J0Y0g2J6Q47
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        PLN_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:32 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:33 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 189,187 of 189,187 bytes (100%) PTPN11_alphamissense.csv
# ID                          file-GkGJQY8JqBj2b7X3fxJZbf7y
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        PTPN11_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:33 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:34 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 96,505 of 96,505 bytes (100%) TNNI3_alphamissense.csv
# ID                          file-GkGJQYQJqBj8qkvYf833x77X
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        TNNI3_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:34 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:35 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 67,950 of 67,950 bytes (100%) TNNT2_alphamissense.csv
# ID                          file-GkGJQYjJqBj41ZGGyX58by4f
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        TNNT2_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:35 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:36 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 145,423 of 145,423 bytes (100%) TPM1_alphamissense.csv
# ID                          file-GkGJQZ0JqBj43J0Y0g2J6Q4F
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        TPM1_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:36 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:36 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 85,614 of 85,614 bytes (100%) TRIM63_alphamissense.csv
# ID                          file-GkGJQZ8JqBj2V81F535JJK3P
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        TRIM63_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:37 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:37 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# [===========================================================>] Uploaded 32,902 of 32,902 bytes (100%) TTR_alphamissense.csv
# ID                          file-GkGJQZQJqBj55bYxFQxZKJVb
# Class                       file
# Project                     project-GGy3Bb0JqBj7zfxY8v4by61X
# Folder                      /selected_genes/hcm/alpha_missensense_annotated
# Name                        TTR_alphamissense.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Thu May 30 19:49:38 2024
# Created by                  skubali
#  via the job                job-GkGFjv0JqBj8JGKXjqbJy8q4
# Last modified               Thu May 30 19:49:38 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
